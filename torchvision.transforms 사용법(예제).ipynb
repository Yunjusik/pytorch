# %%
import os
from glob import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from torch.utils.data import Dataset, DataLoader

import numpy as np
from PIL import Image

# %%
seed = 1

lr = 0.001
momentum = 0.5

batch_size = 64
test_batch_size = 64

epochs = 1
no_cuda = False
log_interval = 100

# %%
train_paths = glob('fastcampus/dataset/mnist_png/training/*/*.png')
test_paths = glob('fastcampus/dataset/mnist_png/testing/*/*.png')

len(train_paths), len(test_paths)
# Out:
# (60000, 10000)

# %% [markdown]
# # Preprocess

# %%
class Dataset(Dataset):
    def __init__(self, data_paths, transform=None):

        self.data_paths = data_paths
        self.transform = transform

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, idx):
        path = self.data_paths[idx]
        image = Image.open(path).convert("L")
        label = int(path.split('\\')[-2])
        
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
data_loader = torch.utils.data.DataLoader(
    Dataset(train_paths, 
            transforms.Compose([
                transforms.RandomHorizontalFlip(), 
                transforms.ToTensor(), 
                transforms.Normalize(
                    mean=[0.406], 
                    std=[0.225])])
           ),
    batch_size=batch_size, 
    shuffle=True
)

# %% [markdown]
# # Understand Better

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path = '아이린.jpg'

# %%
image = Image.open(path)

# %% [markdown]
# https://pytorch.org/docs/stable/torchvision/transforms.html

# %%
import torchvision

# %%
np.array(image).shape
# Out:
# (452, 398, 3)

# %%
torchvision.transforms.CenterCrop(size=(300, 300))(image)
# 이미지 가운데부분만 추리기
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2BB03DC1940>

# %%
torchvision.transforms.ColorJitter(brightness=1, contrast=0, saturation=0, hue=0)(image)
# 실행할때마다 brightness를 바꿔줌 random하게 (1,0으로 조절가능)
# Out:
# <PIL.Image.Image image mode=RGB size=398x452 at 0x2BB03DDA278>

# %%
torchvision.transforms.FiveCrop(size=(300, 300))(image)[0] 
# fivecrop은 이미지를 대략 5부분으로 잘라서 보여줌. 뒤 0~4로 조절 가능
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2BB03DDAE80>

# %%
torchvision.transforms.FiveCrop(size=(300, 300))(image)[3]
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2BB03DDE320>

# %%
torchvision.transforms.FiveCrop(size=(300, 300))(image)[4]
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2BB03DDE4A8>

# %%
torchvision.transforms.Grayscale(num_output_channels=1)(image)
# Out:
# <PIL.Image.Image image mode=L size=398x452 at 0x2BB03DDAB70>

# %%
torchvision.transforms.Pad(padding=(20, 20), fill=0, padding_mode='constant')(image)
# 패딩을 통해 외곽부분 마감처리
# Out:
# <PIL.Image.Image image mode=RGB size=438x492 at 0x2BB03DDE3C8>

# %%
torchvision.transforms.RandomAffine(degrees=90, translate=None, scale=None, shear=None, resample=False, fillcolor=0)(image)
# Out:
# <PIL.Image.Image image mode=RGB size=398x452 at 0x2BB03DDA358>

# %%
transforms = [torchvision.transforms.Grayscale(num_output_channels=1),
              torchvision.transforms.CenterCrop(size=(500, 500)),
              torchvision.transforms.RandomAffine(degrees=90, translate=None, scale=None, shear=None, resample=False, fillcolor=0)]

# %%
torchvision.transforms.RandomApply(transforms, p=0.5)(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=398x452 at 0x2BB03D4E0B8>

# %%
torchvision.transforms.RandomChoice(transforms)(image)
# 위 설정중 랜덤하게 선택
# Out:
# <PIL.Image.Image image mode=RGB size=398x452 at 0x2BB04F5B240>

# %%
torchvision.transforms.RandomCrop(size=(500, 500), padding=None, pad_if_needed=False, fill=0, padding_mode='constant')(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-10b31031a562> in <module>
# ----> 1 torchvision.transforms.RandomCrop(size=(500, 500), padding=None, pad_if_needed=False, fill=0, padding_mode='constant')(image)
#
# ~\Anaconda3\envs\pytorchO\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#     472             img = F.pad(img, (0, self.size[0] - img.size[1]), self.fill, self.padding_mode)
#     473
# --> 474         i, j, h, w = self.get_params(img, self.size)
#     475
#     476         return F.crop(img, i, j, h, w)
#
# ~\Anaconda3\envs\pytorchO\lib\site-packages\torchvision\transforms\transforms.py in get_params(img, output_size)
#     450             return 0, 0, h, w
#     451
# --> 452         i = random.randint(0, h - th)
#     453         j = random.randint(0, w - tw)
#     454         return i, j, th, tw
#
# ~\Anaconda3\envs\pytorchO\lib\random.py in randint(self, a, b)
#     219         """
#     220
# --> 221         return self.randrange(a, b+1)
#     222
#     223     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# ~\Anaconda3\envs\pytorchO\lib\random.py in randrange(self, start, stop, step, _int)
#     197             return istart + self._randbelow(width)
#     198         if step == 1:
# --> 199             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     200
#     201         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (0,-47, -47)

# %%
torchvision.transforms.RandomGrayscale(p=0.5)(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=398x452 at 0x2BB03D4E0B8>

# %%
torchvision.transforms.RandomHorizontalFlip(p=0.5)(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=398x452 at 0x2BB03D4E0B8>

# %%
torchvision.transforms.RandomOrder(transforms)(image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x2BB03DDE978>

# %%
torchvision.transforms.Resize((100, 100), interpolation=Image.BICUBIC)(image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x2BB03DDEA20>

# %% [markdown]
# # Transform on Tensor

# %%
tensor_image = torchvision.transforms.ToTensor()(image)
#이미지를 텐서로 넣음

# %%
trf_image = torchvision.transforms.Normalize(mean=(0,0,0), std=(1,1,1), inplace=False)(tensor_image)
#텐서로 넣은 이미지를  normalize
trf_image = trf_image.numpy()
#텐서형데이터를 numpy로 넘겨 수치로 print 가능

print('Min:', np.min(trf_image), 
      ', Max:', np.max(trf_image), 
      ', Mean:', np.mean(trf_image), 
      ', Std:', np.std(trf_image))
# Out:
# Min: 0.0 , Max: 1.0 , Mean: 0.7352506 , Std: 0.235944

# %%
trf_image.shape
# Out:
# (3, 452, 398)

# %%
trf_image.numpy().transpose(1,2,0).shape
# 위 trf_image.shape은 채널(3)이 맨앞에와있는데, 이를 맨뒤로 보내야 아래와 같이 출력 가능
# Out:
# (452, 398, 3)

# %%
trf_image = torchvision.transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0, inplace=False)(tensor_image)
# 50%확률로 공간 삭제
plt.imshow(trf_image.numpy().transpose(1, 2, 0))

plt.show()
